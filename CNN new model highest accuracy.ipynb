# %%
import numpy as np
import pickle
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
# Import necessary items from Keras
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Activation, Dropout, UpSampling2D
from keras.layers import Conv2DTranspose, Conv2D, MaxPooling2D
from keras.layers import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras import regularizers
from keras.metrics import Precision, Recall
from keras.models import Sequential
from keras.layers import Dense

# %%
def create_model(input_shape, pool_size):
    # Create the actual neural network here
    model = Sequential()
    # Normalizes incoming inputs. First layer needs the input shape to work
    model.add(BatchNormalization(input_shape=input_shape))

    # Below layers were re-named for easier reading of model summary; this not necessary
    # Conv Layer 1
    model.add(Conv2D(8, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Conv1'))

    # Conv Layer 2
    model.add(Conv2D(16, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Conv2'))

    # Pooling 1
    model.add(MaxPooling2D(pool_size=pool_size))

    # Conv Layer 3
    model.add(Conv2D(16, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Conv3'))
    model.add(Dropout(0.2))

    # Conv Layer 4
    model.add(Conv2D(32, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Conv4'))
    model.add(Dropout(0.2))

    # Conv Layer 5
    model.add(Conv2D(32, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Conv5'))
    model.add(Dropout(0.2))

    # Pooling 2
    model.add(MaxPooling2D(pool_size=pool_size))

    # Conv Layer 6
    model.add(Conv2D(64, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Conv6'))
    model.add(Dropout(0.2))

    # Conv Layer 7
    model.add(Conv2D(64, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Conv7'))
    model.add(Dropout(0.2))

    # Pooling 3
    model.add(MaxPooling2D(pool_size=pool_size))

    # Upsample 1
    model.add(UpSampling2D(size=pool_size))

    # Deconv 1
    model.add(Conv2DTranspose(64, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Deconv1'))
    model.add(Dropout(0.2))

    # Deconv 2
    model.add(Conv2DTranspose(64, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Deconv2'))
    model.add(Dropout(0.2))

    # Upsample 2
    model.add(UpSampling2D(size=pool_size))

    # Deconv 3
    model.add(Conv2DTranspose(32, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Deconv3'))
    model.add(Dropout(0.2))

    # Deconv 4
    model.add(Conv2DTranspose(32, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Deconv4'))
    model.add(Dropout(0.2))

    # Deconv 5
    model.add(Conv2DTranspose(16, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Deconv5'))
    model.add(Dropout(0.2))

    # Upsample 3
    model.add(UpSampling2D(size=pool_size))

    # Deconv 6
    model.add(Conv2DTranspose(16, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Deconv6'))

    # Final layer - only including one channel so 1 filter
    model.add(Conv2DTranspose(1, (3, 3), padding='valid', strides=(1,1), activation = 'relu', name = 'Final'))

    return model

# %%
    
    # Load training images
    train_images = pickle.load(open("full_CNN_train.p", "rb" ))

    # Load image labels
    labels = pickle.load(open("full_CNN_labels.p", "rb" ))

    # Make into arrays as the neural network wants these
    train_images = np.array(train_images)
    labels = np.array(labels)

    # Normalize labels - training images get normalized to start in the network
    labels = labels / 255

    # Shuffle images along with their labels, then split into training/validation sets
    train_images, labels = shuffle(train_images, labels)
    # Test size may be 10% or 20%
    X_train, X_val, y_train, y_val = train_test_split(train_images, labels, test_size=0.3)

    # Batch size, epochs and pool size below are all paramaters to fiddle with for optimization
    batch_size = 128
    epochs = 20 
    pool_size = (2, 2)
    input_shape = X_train.shape[1:]

    # Create the neural network
    model = create_model(input_shape, pool_size)

    # Using a generator to help the model use less data
    # Channel shifts help with shadows slightly
    datagen = ImageDataGenerator(channel_shift_range=0.2)
    datagen.fit(X_train)

    # Compiling and training the model
    model.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy',Precision(), Recall()])
    model.fit(datagen.flow(X_train, y_train, batch_size=batch_size), steps_per_epoch=len(X_train)/batch_size,
    epochs=epochs, verbose=1, validation_data=(X_val, y_val))

    # Freeze layers since training is done
    model.trainable = False
    model.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy',Precision(), Recall()])

    # Save model architecture and weights
    model.save('full_CNN_new_model.keras')
    
    #save model architecture in json file
    model_json = model.to_json()
    with open("new_model.json", "w") as json_file:
        json_file.write(model_json)
# Out:
# Epoch 1/20
# 69/69 [==============================] - 350s 5s/step - loss: 0.0585 - accuracy: 0.9010 - precision: 0.8474 - recall: 0.5831 - val_loss: 0.0288 - val_accuracy: 0.9442 - val_precision: 0.9324 - val_recall: 0.8009
# Epoch 2/20
# 69/69 [==============================] - 377s 5s/step - loss: 0.0182 - accuracy: 0.9507 - precision: 0.9532 - recall: 0.8491 - val_loss: 0.0155 - val_accuracy: 0.9515 - val_precision: 0.9446 - val_recall: 0.8785
# Epoch 3/20
# 69/69 [==============================] - 369s 5s/step - loss: 0.0137 - accuracy: 0.9535 - precision: 0.9580 - recall: 0.8743 - val_loss: 0.0116 - val_accuracy: 0.9543 - val_precision: 0.9599 - val_recall: 0.8839
# Epoch 4/20
# 69/69 [==============================] - 372s 5s/step - loss: 0.0117 - accuracy: 0.9549 - precision: 0.9616 - recall: 0.8831 - val_loss: 0.0105 - val_accuracy: 0.9555 - val_precision: 0.9706 - val_recall: 0.8680
# Epoch 5/20
# 69/69 [==============================] - 867s 13s/step - loss: 0.0103 - accuracy: 0.9560 - precision: 0.9645 - recall: 0.8886 - val_loss: 0.0093 - val_accuracy: 0.9562 - val_precision: 0.9701 - val_recall: 0.8788
# Epoch 6/20
# 69/69 [==============================] - 306s 4s/step - loss: 0.0093 - accuracy: 0.9566 - precision: 0.9662 - recall: 0.8923 - val_loss: 0.0088 - val_accuracy: 0.9568 - val_precision: 0.9727 - val_recall: 0.8761
# Epoch 7/20
# 69/69 [==============================] - 365s 5s/step - loss: 0.0087 - accuracy: 0.9571 - precision: 0.9675 - recall: 0.8947 - val_loss: 0.0078 - val_accuracy: 0.9576 - val_precision: 0.9713 - val_recall: 0.8893
# Epoch 8/20
# 69/69 [==============================] - 364s 5s/step - loss: 0.0084 - accuracy: 0.9573 - precision: 0.9681 - recall: 0.8956 - val_loss: 0.0075 - val_accuracy: 0.9577 - val_precision: 0.9709 - val_recall: 0.8958
# Epoch 9/20
# 69/69 [==============================] - 357s 5s/step - loss: 0.0082 - accuracy: 0.9574 - precision: 0.9686 - recall: 0.8965 - val_loss: 0.0074 - val_accuracy: 0.9578 - val_precision: 0.9711 - val_recall: 0.9007
# Epoch 10/20
# 69/69 [==============================] - 363s 5s/step - loss: 0.0079 - accuracy: 0.9576 - precision: 0.9693 - recall: 0.8972 - val_loss: 0.0074 - val_accuracy: 0.9581 - val_precision: 0.9753 - val_recall: 0.8838
# Epoch 11/20
# 69/69 [==============================] - 362s 5s/step - loss: 0.0077 - accuracy: 0.9578 - precision: 0.9703 - recall: 0.8971 - val_loss: 0.0073 - val_accuracy: 0.9582 - val_precision: 0.9755 - val_recall: 0.8826
# Epoch 12/20
# 69/69 [==============================] - 3278s 48s/step - loss: 0.0075 - accuracy: 0.9582 - precision: 0.9721 - recall: 0.8974 - val_loss: 0.0066 - val_accuracy: 0.9592 - val_precision: 0.9800 - val_recall: 0.8951
# Epoch 13/20
# 69/69 [==============================] - 427s 6s/step - loss: 0.0071 - accuracy: 0.9592 - precision: 0.9785 - recall: 0.8958 - val_loss: 0.0060 - val_accuracy: 0.9604 - val_precision: 0.9870 - val_recall: 0.8991
# Epoch 14/20
# 69/69 [==============================] - 426s 6s/step - loss: 0.0065 - accuracy: 0.9600 - precision: 0.9827 - recall: 0.8982 - val_loss: 0.0058 - val_accuracy: 0.9603 - val_precision: 0.9886 - val_recall: 0.8873
# Epoch 15/20
# 69/69 [==============================] - 425s 6s/step - loss: 0.0061 - accuracy: 0.9603 - precision: 0.9842 - recall: 0.8992 - val_loss: 0.0055 - val_accuracy: 0.9606 - val_precision: 0.9889 - val_recall: 0.8896
# Epoch 16/20
# 69/69 [==============================] - 429s 6s/step - loss: 0.0059 - accuracy: 0.9605 - precision: 0.9849 - recall: 0.9000 - val_loss: 0.0058 - val_accuracy: 0.9605 - val_precision: 0.9907 - val_recall: 0.8793
# Epoch 17/20
# 69/69 [==============================] - 426s 6s/step - loss: 0.0057 - accuracy: 0.9606 - precision: 0.9858 - recall: 0.9001 - val_loss: 0.0050 - val_accuracy: 0.9608 - val_precision: 0.9886 - val_recall: 0.8954
# Epoch 18/20
# 69/69 [==============================] - 430s 6s/step - loss: 0.0055 - accuracy: 0.9608 - precision: 0.9863 - recall: 0.9006 - val_loss: 0.0047 - val_accuracy: 0.9610 - val_precision: 0.9888 - val_recall: 0.8992
# Epoch 19/20
# 69/69 [==============================] - 425s 6s/step - loss: 0.0054 - accuracy: 0.9608 - precision: 0.9866 - recall: 0.9011 - val_loss: 0.0049 - val_accuracy: 0.9610 - val_precision: 0.9907 - val_recall: 0.8889
# Epoch 20/20
# 69/69 [==============================] - 438s 6s/step - loss: 0.0053 - accuracy: 0.9609 - precision: 0.9872 - recall: 0.9011 - val_loss: 0.0048 - val_accuracy: 0.9610 - val_precision: 0.9894 - val_recall: 0.8955

# %%
 # Show summary of model\
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (Batch  (None, 80, 160, 3)        12
#  Normalization)
#
#  Conv1 (Conv2D)              (None, 78, 158, 8)        224
#
#  Conv2 (Conv2D)              (None, 76, 156, 16)       1168
#
#  max_pooling2d (MaxPooling2  (None, 38, 78, 16)        0
#  D)
#
#  Conv3 (Conv2D)              (None, 36, 76, 16)        2320
#
#  dropout (Dropout)           (None, 36, 76, 16)        0
#
#  Conv4 (Conv2D)              (None, 34, 74, 32)        4640
#
#  dropout_1 (Dropout)         (None, 34, 74, 32)        0
#
#  Conv5 (Conv2D)              (None, 32, 72, 32)        9248
#
#  dropout_2 (Dropout)         (None, 32, 72, 32)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 16, 36, 32)        0
#  g2D)
#
#  Conv6 (Conv2D)              (None, 14, 34, 64)        18496
#
#  dropout_3 (Dropout)         (None, 14, 34, 64)        0
#
#  Conv7 (Conv2D)              (None, 12, 32, 64)        36928
#
#  dropout_4 (Dropout)         (None, 12, 32, 64)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 16, 64)         0
#  g2D)
#
#  up_sampling2d (UpSampling2  (None, 12, 32, 64)        0
#  D)
#
#  Deconv1 (Conv2DTranspose)   (None, 14, 34, 64)        36928
#
#  dropout_5 (Dropout)         (None, 14, 34, 64)        0
#
#  Deconv2 (Conv2DTranspose)   (None, 16, 36, 64)        36928
#
#  dropout_6 (Dropout)         (None, 16, 36, 64)        0
#
#  up_sampling2d_1 (UpSamplin  (None, 32, 72, 64)        0
#  g2D)
#
#  Deconv3 (Conv2DTranspose)   (None, 34, 74, 32)        18464
#
#  dropout_7 (Dropout)         (None, 34, 74, 32)        0
#
#  Deconv4 (Conv2DTranspose)   (None, 36, 76, 32)        9248
#
#  dropout_8 (Dropout)         (None, 36, 76, 32)        0
#
#  Deconv5 (Conv2DTranspose)   (None, 38, 78, 16)        4624
#
#  dropout_9 (Dropout)         (None, 38, 78, 16)        0
#
#  up_sampling2d_2 (UpSamplin  (None, 76, 156, 16)       0
#  g2D)
#
#  Deconv6 (Conv2DTranspose)   (None, 78, 158, 16)       2320
#
#  Final (Conv2DTranspose)     (None, 80, 160, 1)        145
#
# =================================================================
# Total params: 181693 (709.74 KB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 181693 (709.74 KB)
# _________________________________________________________________
